# %%
from bs4 import BeautifulSoup
import requests

# %%
source_code = requests.get("http://www.statiz.co.kr/stat.php?mid=stat&re=0&ys=2018&ye=2018&se=0&te=&tm=&ty=0&qu=auto&po=0&as=&ae=&hi=&un=&pl=&da=1&o1=WAR_ALL_ADJ&o2=TPA&de=1&lr=0&tr=&cv=&ml=2&pa=0&si=&cn=&sn=100").text
soup = BeautifulSoup(source_code)
# Out:
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
dat = soup.find_all('span')

# %%
data = soup.find_all('span')
data
# Out:
# [<span id="logoimg1div" style="overflow:hidden;"><img id="logoimg1" src="logop.png" style="padding:0;width:240px;height:60px;"/></span>,
#  <span class="input-group-btn" style="padding:0;margin:0;">
#  <button class="btn btn-flat" id="search-btn" name="search" style="margin:0;" type="submit"><i class="fa fa-search"></i>
#  </button>
#  </span>,
#  <span style="color:white;">스탯티즈+</span>,
#  <span style="color:white;">스카이박스</span>,
#  <span style="color:white;">기록실</span>,
#  <span style="color:white;">경기일정</span>,
#  <span style="color:white;">시즌정보</span>,
#  <span style="color:white;">팀정보</span>,
#  <span style="color:white;">선수정보</span>,
#  <span style="color:white;">스페셜</span>,
#  <span style="color:white;">추가정보</span>,
#  <span style="color:#5CD1E5;">OLD SITE</span>,
#  <span style="color:yellow;"><i class="fa fa-user"></i> 로그인</span>,
#  <span style="color:yellow;"><i class="fa fa-sign-in"></i> 회원가입</span>,
#  <span class="caret"></span>,
# ...

# %%
dat[69]
# Out:
# <span style="padding-left:5px;padding-right:5px;">.438</span>

# %%
k=str(data[i])
k[50:54]
# Out:
# '0.47'

# %%
WAR = list()

for i in range(45, 3214, 32):
    WAR.append(data[i])
    
WAR[0]
# Out:
# <span style="padding-left:5px;padding-right:5px;">6.96</span>

# %%
dat = soup.find_all('span')

# %%
k = 45
list_war = []

while  k < 3215:
    data = str(dat[k])
    war = data[50:54]
    list_war.append(war)
    k = k + 32
    
for i in range(len(list_war)):
    list_war[i] = float(list_war[i])
    
list_war
# Out:
# [6.94,
#  6.62,
#  6.42,
#  5.67,
#  5.66,
#  5.3,
#  5.28,
#  4.98,
#  4.94,
#  4.79,
#  4.78,
#  4.73,
#  4.66,
#  4.55,
#  4.51,
#  4.21,
#  3.91,
#  3.84,
#  3.79,
#  3.75,
#  3.72,
#  3.68,
#  3.56,
#  3.56,
#  3.53,
#  3.52,
#  3.48,
#  3.42,
#  3.4,
#  3.35,
#  3.29,
#  3.2,
#  3.05,
#  3.05,
#  3.03,
#  2.93,
#  2.85,
#  2.83,
#  2.75,
#  2.67,
#  2.51,
#  2.41,
#  2.35,
#  2.23,
#  2.14,
#  2.1,
#  2.1,
#  1.99,
#  1.97,
#  1.91,
#  1.87,
#  1.87,
#  1.84,
#  1.75,
#  1.71,
#  1.7,
#  1.64,
#  1.58,
#  1.58,
#  1.55,
#  1.53,
#  1.41,
#  1.38,
#  1.38,
#  1.37,
#  1.37,
#  1.35,
#  1.3,
#  1.26,
#  1.19,
#  1.06,
#  1.05,
#  1.04,
#  1.02,
#  1.0,
#  0.98,
#  0.95,
#  0.92,
#  0.91,
#  0.91,
#  0.9,
#  0.85,
#  0.84,
#  0.79,
#  0.79,
#  0.77,
#  0.77,
#  0.74,
#  0.7,
#  0.67,
#  0.66,
#  0.61,
#  0.59,
#  0.57,
#  0.53,
#  0.49,
#  0.48,
#  0.48,
#  0.47,
#  0.47]

# %%
list_wpa.append(1.53)

# %%
k = 72
list_wpa = []

while  k < 3215:
    data = str(dat[k])
    wpa = data[50:54]
    list_wpa.append(wpa)
    k = k + 32
    
for i in range(len(list_wpa)):
    list_wpa[i] = float(list_wpa[i])

# %%
list_wpa
# Out:
# [5.8,
#  6.44,
#  3.91,
#  5.45,
#  5.41,
#  4.35,
#  5.89,
#  4.06,
#  5.7,
#  4.23,
#  3.95,
#  3.44,
#  3.9,
#  3.55,
#  4.73,
#  2.1,
#  4.23,
#  4.34,
#  1.69,
#  2.9,
#  4.72,
#  -0.6,
#  1.01,
#  1.89,
#  4.03,
#  2.5,
#  2.84,
#  3.97,
#  1.96,
#  3.82,
#  4.07,
#  1.95,
#  1.13,
#  2.16,
#  3.46,
#  0.96,
#  1.22,
#  2.62,
#  2.43,
#  0.17,
#  1.52,
#  1.65,
#  0.9,
#  1.03,
#  0.7,
#  1.23,
#  2.81,
#  -0.5,
#  -0.8,
#  2.36,
#  3.15,
#  0.62,
#  -0.7,
#  -0.7,
#  -0.0,
#  0.72,
#  2.9,
#  1.16,
#  0.39,
#  1.34,
#  0.32,
#  2.57,
#  2.63,
#  0.77,
#  0.05,
#  0.37,
#  0.16,
#  1.04,
#  -0.6,
#  0.78,
#  0.89,
#  2.12,
#  0.42,
#  0.75,
#  0.25,
#  0.65,
#  1.7,
#  1.78,
#  -0.3,
#  1.51,
#  1.62,
#  1.63,
#  -0.9,
#  -1.0,
#  1.73,
#  -0.3,
#  -0.2,
#  0.31,
#  -0.3,
#  1.15,
#  1.21,
#  2.43,
#  0.35,
#  0.38,
#  0.05,
#  -0.4,
#  -1.4,
#  1.46,
#  -0.8,
#  1.53]

# %%
k = 69
list_woba = []

while  k < 3215:
    data = str(dat[k])
    woba = data[50:54]
    list_woba.append(woba)
    k = k + 32
    
for i in range(len(list_woba)):
    list_woba[i] = float(list_woba[i])

# %%
list_woba.append(0.364)

# %%
list_woba
# Out:
# [0.438,
#  0.478,
#  0.431,
#  0.421,
#  0.41,
#  0.409,
#  0.432,
#  0.407,
#  0.411,
#  0.424,
#  0.422,
#  0.396,
#  0.413,
#  0.385,
#  0.387,
#  0.397,
#  0.398,
#  0.415,
#  0.379,
#  0.391,
#  0.391,
#  0.368,
#  0.36,
#  0.366,
#  0.399,
#  0.385,
#  0.404,
#  0.371,
#  0.376,
#  0.376,
#  0.364,
#  0.347,
#  0.37,
#  0.37,
#  0.36,
#  0.363,
#  0.384,
#  0.329,
#  0.38,
#  0.356,
#  0.357,
#  0.377,
#  0.397,
#  0.365,
#  0.342,
#  0.339,
#  0.375,
#  0.355,
#  0.337,
#  0.406,
#  0.377,
#  0.347,
#  0.331,
#  0.338,
#  0.381,
#  0.337,
#  0.369,
#  0.346,
#  0.368,
#  0.382,
#  0.388,
#  0.355,
#  0.362,
#  0.353,
#  0.37,
#  0.324,
#  0.34,
#  0.365,
#  0.337,
#  0.341,
#  0.402,
#  0.445,
#  0.326,
#  0.447,
#  0.311,
#  0.328,
#  0.351,
#  0.335,
#  0.367,
#  0.354,
#  0.353,
#  0.31,
#  0.304,
#  0.32,
#  0.333,
#  0.305,
#  0.312,
#  0.34,
#  0.351,
#  0.314,
#  0.369,
#  0.319,
#  0.342,
#  0.512,
#  0.356,
#  0.302,
#  0.302,
#  0.351,
#  0.319,
#  0.364]

# %%
source_code_2 = requests.get("http://www.statiz.co.kr/stat.php?mid=stat&re=0&ys=2018&ye=2018&se=0&te=&tm=&ty=0&qu=auto&po=0&as=&ae=&hi=&un=&pl=&da=1&o1=WAR_ALL_ADJ&o2=TPA&de=1&lr=0&tr=&cv=&ml=2&sn=100&pa=100&si=&cn=").text
soup_2 = BeautifulSoup(source_code_2)
# Out:
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
dat_2 = soup_2.find_all('span')
dat_2
# Out:
# [<span id="logoimg1div" style="overflow:hidden;"><img id="logoimg1" src="logop.png" style="padding:0;width:240px;height:60px;"/></span>,
#  <span class="input-group-btn" style="padding:0;margin:0;">
#  <button class="btn btn-flat" id="search-btn" name="search" style="margin:0;" type="submit"><i class="fa fa-search"></i>
#  </button>
#  </span>,
#  <span style="color:white;">스탯티즈+</span>,
#  <span style="color:white;">스카이박스</span>,
#  <span style="color:white;">기록실</span>,
#  <span style="color:white;">경기일정</span>,
#  <span style="color:white;">시즌정보</span>,
#  <span style="color:white;">팀정보</span>,
#  <span style="color:white;">선수정보</span>,
#  <span style="color:white;">스페셜</span>,
#  <span style="color:white;">추가정보</span>,
#  <span style="color:#5CD1E5;">OLD SITE</span>,
#  <span style="color:yellow;"><i class="fa fa-user"></i> 로그인</span>,
#  <span style="color:yellow;"><i class="fa fa-sign-in"></i> 회원가입</span>,
#  <span class="caret"></span>,
# ...

# %%
k = 45
list_war_2_a = []

while  k < 238:
    data = str(dat_2[k])
    war = data[50:54]
    list_war_2_a.append(war)
    k = k + 32
    
for i in range(len(list_war_2_a)):
    list_war_2_a[i] = float(list_war_2_a[i])
    
list_war_2_a
# Out:
# [0.47, 0.44, 0.39, 0.34, 0.34, 0.33, 0.33]

# %%
dat_2[268]
# Out:
# <span style="padding-left:5px;padding-right:5px;">0.32</span>

# %%
k = 268
list_war_2_b = []

while  k < 1165:
    data = str(dat_2[k])
    war = data[50:54]
    list_war_2_b.append(war)
    k = k + 32
    
for i in range(len(list_war_2_b)):
    list_war_2_b[i] = float(list_war_2_b[i])
    
list_war_2_b
# Out:
# [0.32,
#  0.32,
#  0.3,
#  0.28,
#  0.26,
#  0.26,
#  0.26,
#  0.21,
#  0.19,
#  0.18,
#  0.17,
#  0.16,
#  0.15,
#  0.14,
#  0.12,
#  0.11,
#  0.11,
#  0.1,
#  0.1,
#  0.09,
#  0.09,
#  0.08,
#  0.06,
#  0.06,
#  0.04,
#  0.03,
#  0.03,
#  0.03,
#  0.03]

# %%
k = 1195
list_war_2_c = []

while  k < 1259:
    data = str(dat_2[k])
    war = data[50:54]
    list_war_2_c.append(war)
    k = k + 32
    
for i in range(len(list_war_2_c)):
    list_war_2_c[i] = float(list_war_2_c[i])
# Out:
# ['0.03', '0.02']

# %%
list_war_2_c
# Out:
# [0.03, 0.02, 0.02, 0.01]

# %%
list_war_2_a+list_war_2_b+list_war_2_c
# Out:
# [0.47,
#  0.44,
#  0.39,
#  0.34,
#  0.34,
#  0.33,
#  0.33,
#  0.32,
#  0.32,
#  0.3,
#  0.28,
#  0.26,
#  0.26,
#  0.26,
#  0.21,
#  0.19,
#  0.18,
#  0.17,
#  0.16,
#  0.15,
#  0.14,
#  0.12,
#  0.11,
#  0.11,
#  0.1,
#  0.1,
#  0.09,
#  0.09,
#  0.08,
#  0.06,
#  0.06,
#  0.04,
#  0.03,
#  0.03,
#  0.03,
#  0.03,
#  0.03,
#  0.02,
#  0.02,
#  0.01]

# %%
source_team = requests.get("http://www.statiz.co.kr/salary.php?opt=1").text
soup_team = BeautifulSoup(source_team)
# Out:
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
soup_team
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>STATIZ</title>
# <!-- Tell the browser to be responsive to screen width -->
# <!-- meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport" -->
# <!-- Bootstrap 3.3.5 -->
# <link href="bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- Font Awesome -->
# <!--<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">-->
# <!--<link rel="stylesheet" href="https://cdn.jsdelivr.net/fontawesome/4.7.0/css/font-awesome.min.css">-->
# <link href="css/font-awesome-4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <!-- Ionicons -->
# <link href="https://code.ionicframework.com/ionicons/2.0.1/css/ionicons.min.css" rel="stylesheet"/>
# <!-- Theme style -->
# <link href="dist/css/AdminLTE.min.css" rel="stylesheet"/>
# <!-- AdminLTE Skins. Choose a skin from the css/skins
# ...

# %%
soup_team.find_all("span")
# Out:
# [<span id="logoimg1div" style="overflow:hidden;"><img id="logoimg1" src="logop.png" style="padding:0;width:240px;height:60px;"/></span>,
#  <span class="input-group-btn" style="padding:0;margin:0;">
#  <button class="btn btn-flat" id="search-btn" name="search" style="margin:0;" type="submit"><i class="fa fa-search"></i>
#  </button>
#  </span>,
#  <span style="color:white;">스탯티즈+</span>,
#  <span style="color:white;">스카이박스</span>,
#  <span style="color:white;">기록실</span>,
#  <span style="color:white;">경기일정</span>,
#  <span style="color:white;">시즌정보</span>,
#  <span style="color:white;">팀정보</span>,
#  <span style="color:white;">선수정보</span>,
#  <span style="color:white;">스페셜</span>,
#  <span style="color:white;">추가정보</span>,
#  <span style="color:#5CD1E5;">OLD SITE</span>,
#  <span style="color:yellow;"><i class="fa fa-user"></i> 로그인</span>,
#  <span style="color:yellow;"><i class="fa fa-sign-in"></i> 회원가입</span>,
#  <span class="caret"></span>,
#  <span class="caret"></span>,
# ...
